# %%
# !pip install python-pptx

import datetime
import os
from pytz import timezone
from pptx import Presentation
from pptx.util import Inches
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#      |████████████████████████████████| 9.3 MB 7.6 MB/s
# ...
#      |████████████████████████████████| 148 kB 70.0 MB/s
# ...
#   Created wheel for python-pptx: filename=python_pptx-0.6.19-py3-none-any.whl size=469952 sha256=7092341d17628aebf258225257a7e356847366ac99225e04ccb3cb9b37c935e6
#   Stored in directory: /root/.cache/pip/wheels/17/2f/48/d23f362a5c4728f063b61c4be61e23c2415da1a371f902e5b4
# Successfully built python-pptx
# ...
# Mounted at /content/drive

# %%
# layout(slide_masters) 파일  
prs = Presentation("/content/drive/MyDrive/Robostar/PPT_test/test_layout.pptx")

# slide_masters 모든 layout을 적용시켜 저장하는 함수
def check_all_layout():
  for master in prs.slide_masters:
    for layout in master.slide_layouts:
      slide = prs.slides.add_slide(layout)

  prs.save("/content/drive/MyDrive/Robostar/PPT_test/test_ppt.pptx")

# slide의 모든 placeholder를 출력하는 함수
def check_placeholder(slide):
  for  shape in slide.placeholders:
    print('%d %s' % (shape.placeholder_format.idx, shape.name))

def make_pptx():
  ######################################################################################### Page 1. Title

  # slide_masters 0번의 layout 0번 : Title layout 지정 및 페이지 추가
  slide = prs.slides.add_slide(prs.slide_masters[0].slide_layouts[0])

  # 지정한 slide에 Title 작성
  slide.placeholders[0].text = "Fitting Model Graph Report"

  # 지정한 slide에 SubTitle 작성
  slide.placeholders[1].text = str(datetime.datetime.now(timezone("UTC")).astimezone(timezone("Asia/Seoul")).strftime("%Y-%m-%d %H:%M:%S")) + " Report"
  ######################################################################################### Page 2. Graph
  
  # slide_masters 0번의 layout 1번 : Seccond layout 지정 및 페이지 추가
  slide = prs.slides.add_slide(prs.slide_masters[0].slide_layouts[1])

  # 이미지 추가룰 위한 이미지 저장 폴더 경로 설정
  # 이미지 양식 : 이미지 순서대로 ppt에 첨부하므로 정렬 결과가 순차적으로 적용되는 이름이 되어야 함
  image_folder_path = "/content/drive/MyDrive/Robostar/PPT_test"

  # 해당 경로 안 확장자 .png 파일 경로를 img_path_list에 저장
  img_file_list = []
  file_list = os.listdir(image_folder_path)

  for file in file_list:
    if file.endswith(".png"):
      img_file_list.append(file)
  img_file_list = sorted(img_file_list)
  print(img_file_list)
  
  # Title 작성
  slide.placeholders[0].text = "Fitting Model Graph"

  ########################################## J1
  # 이미지 추가 
  left, top = Inches(0.49), Inches(1.2)   # 여백 인치 설정
  width, height = Inches(3.5), Inches(1.25)   # 이미지 넓이, 길이 인치 설정
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[0], left, top, width=width, height=height)

  # 두 번째 이미지 추가
  left, top = Inches(0.49), Inches(2.45)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[1], left, top, width=width, height=height)
  
  # 세 번째 이미지 추가
  left, top = Inches(2.24), Inches(2.45)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[2], left, top, width=width, height=height)

  ########################################## J2
  # 이미지 추가 
  left, top = Inches(4.35), Inches(1.2)
  width, height = Inches(3.5), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[3], left, top, width=width, height=height)

  # 두 번째 이미지 추가
  left, top = Inches(4.35), Inches(2.45)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[4], left, top, width=width, height=height)
  
  # 세 번째 이미지 추가
  left, top = Inches(6.1), Inches(2.45)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[5], left, top, width=width, height=height)

  ########################################## J3
  # 이미지 추가 
  left, top = Inches(8.21), Inches(1.2)
  width, height = Inches(3.5), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[6], left, top, width=width, height=height)

  # 두 번째 이미지 추가
  left, top = Inches(8.21), Inches(2.45)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[7], left, top, width=width, height=height)
  
  # 세 번째 이미지 추가
  left, top = Inches(9.96), Inches(2.45)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[8], left, top, width=width, height=height)

  ########################################## J4
  # 이미지 추가 
  left, top = Inches(0.49), Inches(4)
  width, height = Inches(3.5), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[9], left, top, width=width, height=height)

  # 두 번째 이미지 추가
  left, top = Inches(0.49), Inches(5.25)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[10], left, top, width=width, height=height)
  
  # 세 번째 이미지 추가
  left, top = Inches(2.24), Inches(5.25)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[11], left, top, width=width, height=height)

  ########################################## J5
  # 이미지 추가 
  left, top = Inches(4.35), Inches(4)
  width, height = Inches(3.5), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[12], left, top, width=width, height=height)

  # 두 번째 이미지 추가
  left, top = Inches(4.35), Inches(5.25)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[13], left, top, width=width, height=height)
  
  # 세 번째 이미지 추가
  left, top = Inches(6.1), Inches(5.25)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[14], left, top, width=width, height=height)

  ########################################## J6
  # 이미지 추가 
  left, top = Inches(8.21), Inches(4)
  width, height = Inches(3.5), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[15], left, top, width=width, height=height)

  # 두 번째 이미지 추가
  left, top = Inches(8.21), Inches(5.25)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[16], left, top, width=width, height=height)
  
  # 세 번째 이미지 추가
  left, top = Inches(9.96), Inches(5.25)
  width, height = Inches(1.75), Inches(1.25)
  slide.shapes.add_picture(image_folder_path + '/' + img_file_list[17], left, top, width=width, height=height)

  prs.save("/content/drive/MyDrive/Robostar/PPT_test/test_ppt.pptx")
  
make_pptx()
# Out:
# ['fitting_J1.png', 'fitting_J1_1.png', 'fitting_J1_2.png', 'fitting_J2.png', 'fitting_J2_1.png', 'fitting_J2_2.png', 'fitting_J3.png', 'fitting_J3_1.png', 'fitting_J3_2.png', 'fitting_J4.png', 'fitting_J4_1.png', 'fitting_J4_2.png', 'fitting_J5.png', 'fitting_J5_1.png', 'fitting_J5_2.png', 'fitting_J6.png', 'fitting_J6_2.png', 'fitting_j6_1.png']
